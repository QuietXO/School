# %% [markdown]
# # **_Chess Piece Classification_**
#
# ### __*This Neural Network is supposed to determine what kind of Chess Piece is in the Image*__

# %% [markdown]
# <br>
#
# ### __*Import Libraries and choose the device*__

# %%
# Import of the Libraries
import os
import nn_func

# Torch libraries
import torch
from torch.utils.data import DataLoader

# Device config
GPU = nn_func.pick_device()
# Out:
# Using the Graphics Card

# %% [markdown]
# <br>
#
# ### __*Dataset Preparation*__

# %%
# Define the directory
FILE_PATH = './data/chess/pieces'           # Sub-Folders Location
TRAIN_CSV = './data/chess/train_data.csv'   # Train CSV Location
TEST_CSV = './data/chess/test_data.csv'     # Test CSV Location
CATEGORIES = os.listdir(FILE_PATH)          # Turn Sub-Folder names into a list
N_CLASSES = len(CATEGORIES)                 # Number of different classes

# Image Dimensions
IMG_SIZE = 85               # 85*85 pixels

# Normalized Transformation
MEAN, STD = nn_func.dataset.get_normal(FILE_PATH, IMG_SIZE, IMG_SIZE)
trans_normal = nn_func.dataset.trans_normal(IMG_SIZE, IMG_SIZE, MEAN, STD)

# Create the .csv file & dictionary
indexing = nn_func.dataset.create_csv(FILE_PATH, train_csv=TRAIN_CSV, test_csv=TEST_CSV,
                                  rewrite=True, split=True, test_ratio=0.2, mul=16)

# Create the Datasets
train_dataset = nn_func.dataset.CustomDataset(FILE_PATH, TRAIN_CSV, transform=trans_normal)
test_dataset = nn_func.dataset.CustomDataset(FILE_PATH, TEST_CSV, transform=trans_normal)

# Create the DataLoaders
train_loader = DataLoader(dataset=train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# #### __*Look at some data*__

# %%
# Get dataset overview
nn_func.visual.overview(train_dataset, test_dataset, indexing)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Batch size: 64 | Colour size: 1 | Image Size: 85*85 pixels
#      Class Train Data Test Data Total
# 0     king        448        96   544
# 1     pawn       3072       752  3824
# 2     rook        928       224  1152
# 3    queen        448        96   544
# 4   bishop        864       208  1072
# 5   knight        912       224  1136
#
# T:       6       6672      1600  8272

# %% [markdown]
# <br>
#
# ### __*Topology Testing*__

# %%
# Hyper-parameters
num_epochs = 15            # How many times to repeat learning
learning_rate = 0.001      # How quickly should it learn
criterion = torch.nn.CrossEntropyLoss()  # Choose type of Loss

# %%
# Create the 1st Model
model = nn_func.model.Model1(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the 2nd Model
model = nn_func.model.Model2(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the 3rd Model
model = nn_func.model.Model3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the 4th Model
model = nn_func.model.Model4(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the 5th Model
model = nn_func.model.Model5(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the 6th Model
model = nn_func.model.Model6(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the 7th Model
model = nn_func.model.Model7(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %% [markdown]
# <br>
#
# ### __*Optimizer Testing*__

# %%
# Hyper-parameters
num_epochs = 15            # How many times to repeat learning
learning_rate = 0.001      # How quickly should it learn
criterion = torch.nn.CrossEntropyLoss()  # Choose type of Loss

# %%
# Create the Model with SGD optimizer
model = nn_func.model.Model3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the Model with ASGD optimizer
model = nn_func.model.Model3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.ASGD(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the Model with Adam optimizer
model = nn_func.model.Model3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the Model with AdamW optimizer
model = nn_func.model.Model3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the Model with Ada-delta optimizer
model = nn_func.model.Model3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.Adadelta(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %% [markdown]
# <br>
#
# ### __*Learning Rate Testing*__

# %%
# Hyper-parameters
num_epochs = 15            # How many times to repeat learning
criterion = torch.nn.CrossEntropyLoss()  # Choose type of Loss

# %%
# Create the Model with Learning Rate = 0.01
model = nn_func.model.Model3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=0.01)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the Model with Learning Rate = 0.005
model = nn_func.model.Model3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=0.005)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the Model with Learning Rate = 0.003
model = nn_func.model.Model3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=0.003)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the Model with Learning Rate = 0.001
model = nn_func.model.Model3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the Model with Learning Rate = 0.0005
model = nn_func.model.Model3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0005)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %% [markdown]
# <br>
#
# ### __*Activation Function Testing*__

# %%
# Hyper-parameters
num_epochs = 15            # How many times to repeat learning
learning_rate = 0.001      # How quickly should it learn
criterion = torch.nn.CrossEntropyLoss()  # Choose type of Loss

# %%
# Create the Model with Learning Rate = 0.001
model = nn_func.model.ReLUModel3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the Model with Learning Rate = 0.001
model = nn_func.model.SigmoidModel3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %%
# Create the Model with Learning Rate = 0.001
model = nn_func.model.TanhModel3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
_ = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=False)

# %% [markdown]
# <br>
#
# ### __*Final Model*__

# %%
# Hyper-parameters
num_epochs = 15            # How many times to repeat learning
learning_rate = 0.001      # How quickly should it learn
criterion = torch.nn.CrossEntropyLoss()  # Choose type of Loss

# Create the Final Model
model = nn_func.model.ReLUModel3(IMG_SIZE, IMG_SIZE, N_CLASSES).to(GPU)
# Choose type of Loss & Optimization function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Train the Model
nn_func.model.train_model(model, train_loader, criterion, optimizer, num_epochs, device=GPU)
# Test the Model
res, y_pred, y_true = nn_func.model.load_model(model, test_loader, CATEGORIES, show_wrongs=True)
# Show the Confusion Matrix
nn_func.visual.matrix(y_pred, y_true, CATEGORIES, 'data/chess/ConfusionMatrix.png')
# Out:
# --- Training Started ---
# Epoch 1 / 15 | Step 209 / 209 | Loss: 1.0402
# Epoch 2 / 15 | Step 209 / 209 | Loss: 0.6455
# Epoch 3 / 15 | Step 209 / 209 | Loss: 0.4588
# Epoch 4 / 15 | Step 209 / 209 | Loss: 0.3757
# Epoch 5 / 15 | Step 209 / 209 | Loss: 0.2886
# Epoch 6 / 15 | Step 209 / 209 | Loss: 0.2400
# Epoch 7 / 15 | Step 209 / 209 | Loss: 0.2299
# Epoch 8 / 15 | Step 209 / 209 | Loss: 0.1981
# Epoch 9 / 15 | Step 209 / 209 | Loss: 0.1923
# Epoch 10 / 15 | Step 209 / 209 | Loss: 0.1886
# Epoch 11 / 15 | Step 209 / 209 | Loss: 0.1613
# Epoch 12 / 15 | Step 209 / 209 | Loss: 0.1293
# Epoch 13 / 15 | Step 209 / 209 | Loss: 0.1047
# Epoch 14 / 15 | Step 209 / 209 | Loss: 0.1226
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 15 / 15 | Step 209 / 209 | Loss: 0.1062
# --- Training Finished ---
#
# Class: king | Predicted: knight
# ...
